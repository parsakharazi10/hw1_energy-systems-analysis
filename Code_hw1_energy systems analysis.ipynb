# %%
# محاسبه راندمان (Efficiency) نیروگاه

# داده های نیروگاه
input_power_plant = 2.45 + 16.99 + 435.5 + 62.9 + 41.59  # ورودی‌ها
output_power_plant = 201.46  # خروجی

# محاسبه راندمان
efficiency_power_plant = output_power_plant / input_power_plant  # راندمان نیروگاه
efficiency_power_plant_percentage = efficiency_power_plant * 100  # تبدیل به درصد

# محاسبه تفاوت بین ورودی و خروجی (L)
L_power_plant = input_power_plant - output_power_plant  # تفاوت ورودی و خروجی نیروگاه

# نمایش نتایج نیروگاه
print("راندمان نیروگاه: {:.2f} → {:.0f}%".format(efficiency_power_plant, efficiency_power_plant_percentage))
print("L نیروگاه = {:.2f} Mboe".format(L_power_plant))
# محاسبه راندمان واحدهای کک سازی

# داده های واحد کک سازی
input_coke_sulfur = 5.10  # ورودی
output_coke_sulfur = 2.4  # خروجی

# محاسبه راندمان
efficiency_coke_sulfur = output_coke_sulfur / input_coke_sulfur  # راندمان
efficiency_coke_sulfur_percentage = efficiency_coke_sulfur * 100  # تبدیل به درصد

# محاسبه تفاوت بین ورودی و خروجی (L)
L_coke_sulfur = input_coke_sulfur - output_coke_sulfur  # تفاوت ورودی و خروجی

# نمایش نتایج واحد کک سازی
print("راندمان واحدهای کک سازی: {:.2f} → {:.0f}%".format(efficiency_coke_sulfur, efficiency_coke_sulfur_percentage))
print("L واحدهای کک سازی = {:.2f} Mboe".format(L_coke_sulfur))
# محاسبه راندمان پالایشگاه

# داده های پالایشگاه
output_refinery = (0.32 + 16.8 + 188.4 + 5.5 + 14.5 + 233.7 + 148.9 + 28 + 226.08 + 1660 + 28.51 + 27.62)  #خروجی
input_refinery = 587.87 + 122.3 + 38.9 + 3.7 + 2168.2  #ورودی

# محاسبه راندمان
efficiency_refinery = output_refinery / input_refinery  # راندمان پالایشگاه
efficiency_refinery_percentage = efficiency_refinery * 100  # تبدیل به درصد

# محاسبه تفاوت بین ورودی و خروجی (L)
L_refinery = input_refinery - output_refinery  # تفاوت ورودی و خروجی پالایشگاه

# نمایش نتایج پالایشگاه
print("راندمان پالایشگاه: {:.2f} → {:.0f}%".format(efficiency_refinery, efficiency_refinery_percentage))
print("L پالایشگاه = {:.2f} Mboe".format(L_refinery))
# Out:
# راندمان نیروگاه: 0.36 → 36%
# L نیروگاه = 357.97 Mboe
# راندمان واحدهای کک سازی: 0.47 → 47%
# L واحدهای کک سازی = 2.70 Mboe
# راندمان پالایشگاه: 0.88 → 88%
# L پالایشگاه = 342.64 Mboe

# %%
# محاسبه راندمان (Efficiency) برای تولید برق و گرما

# داده‌های تولید برق و گرما
input_electricity_heat = 665619  # ورودی
output_electricity_heat = 343071.1  # خروجی

# محاسبه راندمان
efficiency_electricity_heat = output_electricity_heat / input_electricity_heat  # راندمان تولید برق و گرما
efficiency_electricity_heat_percentage = efficiency_electricity_heat * 100  # تبدیل به درصد

# نمایش نتایج
print("راندمان تولید برق و گرما: {:.2f} → {:.0f}%".format(efficiency_electricity_heat, efficiency_electricity_heat_percentage))


# محاسبه راندمان صنایع پتروشیمی و پالایشگاه‌ها

# داده‌های پالایشگاه و صنایع پتروشیمی
input_refineries_petrochemical = 769433  # ورودی
output_refineries_petrochemical = 763655  # خروجی

# محاسبه راندمان
efficiency_refineries_petrochemical = output_refineries_petrochemical / input_refineries_petrochemical  # راندمان
efficiency_refineries_petrochemical_percentage = efficiency_refineries_petrochemical * 100  # تبدیل به درصد

# نمایش نتایج
print("راندمان پالایشگاه‌ها و صنایع پتروشیمی: {:.2f} → {:.0f}%".format(efficiency_refineries_petrochemical, efficiency_refineries_petrochemical_percentage))


# محاسبه راندمان کوره‌های کک سازی

# داده‌های کوره‌های کک سازی
input_coke_ovens = 36454.0  # ورودی
output_coke_ovens = 33926  # خروجی

# محاسبه راندمان
efficiency_coke_ovens = output_coke_ovens / input_coke_ovens  # راندمان کوره‌های کک سازی
efficiency_coke_ovens_percentage = efficiency_coke_ovens * 100  # تبدیل به درصد

# نمایش نتایج
print("راندمان کوره‌های کک سازی: {:.2f} → {:.0f}%".format(efficiency_coke_ovens, efficiency_coke_ovens_percentage))
# Out:
# راندمان تولید برق و گرما: 0.52 → 52%
# راندمان پالایشگاه‌ها و صنایع پتروشیمی: 0.99 → 99%
# راندمان کوره‌های کک سازی: 0.93 → 93%

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = {
    'year': [1389, 1390, 1391, 1392, 1393, 1394, 1395, 1396, 1397, 1398, 1399],
    'gasoline': [0.093917, 0.14743, 0.116602, 0.178315, 0.121531, 0.081926081, 0.079209, 0.06105, 0.072041, 0.126079, 0.115968],
    'mazot': [0.160681, 0.215621, 0.24788, 0.251569, 0.160865, 0.107060261, 0.069114, 0.051132, 0.049856, 0.075881, 0.076657],
    'light_gas': [0.742319, 0.633631, 0.632213, 0.562845, 0.713363, 0.807767296, 0.848137, 0.881469, 0.873744, 0.797371, 0.803762],
    'coke': [0, 0, 0, 0, 6.66e-05, 6.66e-05, 0.000163, 0.000143, 0.000164, 0.000163, 0.000285],
    'bfg': [0.003083, 0.003678, 0.003304, 0.004061, 0.003905, 0.003250862, 0.00354, 0.003737, 0.003644, 0.003604, 0.003621]
}

# Convert the data into a DataFrame
df = pd.DataFrame(data)

# Plotting the data
plt.figure(figsize=(10, 6))
for fuel in ['gasoline', 'mazot', 'light_gas', 'coke', 'bfg']:
    plt.plot(df['year'], df[fuel], marker='o', label=fuel)

# Customizing the plot

plt.xlabel('Year')

plt.legend(title="Fuel Type")
plt.grid(True)
plt.xticks(df['year'])

# Show the plot
plt.show()
